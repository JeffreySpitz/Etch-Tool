# %%
# %matplotlib notebook

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg

# Turn interactive plotting off
plt.ioff()
try:
    from PIL import Image
except ImportError:
    raise SystemExit("Pillow must be installed to run this example")
# plt.figure(figsize=(4,4),constrained_layout=True)
# fig, axs = plt.subplots(1, 1)
# plt.plot([0,1, 2, 3,4],[.3,.5,.4,.7,.2])
# plt.axis([1, 3, 0, 1])
# plt.axis('off')
# plt.set_position([0,0,1,1])

fig, ax = plt.subplots(figsize=(4,4),constrained_layout=True)
ax.plot([0,1, 2, 3,4],[.3,.5,.4,.7,.2])
ax.axis([1, 3, 0, 1])
ax.axis('off')
ax.set_position([0, 0, 1, 1])
# fig, axs = plt.subplots(1, 1)
# plt.plot([0,1, 2, 3,4],[.3,.5,.4,.7,.2])
# plt.axis([1, 3, 0, 1])
# plt.axis('off')
# plt.set_position([0,0,1,1])

canvas = plt.get_current_fig_manager().canvas

agg = canvas.switch_backends(FigureCanvasAgg)
agg.draw()
s = agg.tostring_rgb()

# get the width and the height to resize the matrix
l, b, w, h = agg.figure.bbox.bounds
w, h = int(w), int(h)
w,h
# Out:
# (400, 400)

# %%
X = np.frombuffer(s, dtype='uint8')
X.shape = h, w, 3
img2 = np.pad(X, ((1, 1), (1, 1),(0,0)), 'constant', constant_values=(30, 30))
img2.shape
# Out:
# (402, 402, 3)

# %%
imgplot = plt.imshow(img2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot([0,1, 2, 3,4],[.3,.5,.4,.7,.2])
plt.axis([1, 3, 0, 1])
fig = plt.figure(frameon=False)
fig.set_size_inches(w,h)

# %%
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)

# %%
ax.imshow(your_image, aspect='normal')

# %%
type(im)
# Out:
# PIL.Image.Image

# %%
agg

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg
import matplotlib.patches as patches

# %%
plt.plot([0,1, 2, 3,4],[.3,.5,.4,.7,.2])
plt.axis([1, 3, 0, 1])
plt.xlabel('time (s)')
plt.ylabel('current (nA)')
plt.title('Gaussian colored noise')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
fig.add_subplot(111)
fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
width, height = fig.get_size_inches() * fig.get_dpi()
img = image.reshape(int(height), int(width), 3)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-11-c7da13c508c7> in <module>()
# ----> 1 image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
#       2 width, height = fig.get_size_inches() * fig.get_dpi()
#       3 img = image.reshape(int(height), int(width), 3)
#
# /apps/share64/debian7/anaconda/anaconda2-5.1/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in tostring_rgb(self)
#     464         bytes
#     465         '''
# --> 466         return self.renderer.tostring_rgb()
#     467
#     468     def tostring_argb(self):
#
# AttributeError: 'FigureCanvasNbAgg' object has no attribute 'renderer'

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg
import matplotlib.patches as patches
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

fig = Figure()
fig.tight_layout(pad=0)
canvas = FigureCanvas(fig)
ax = fig.gca()
# Out:
# /apps/share64/debian7/anaconda/anaconda2-5.1/lib/python2.7/site-packages/matplotlib/tight_layout.py:207: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")

# %%
ax.plot([0,1, 2, 3,4],[.3,.5,.4,.7,.2])
ax.axis([1, 3, 0, 1])
ax.axis('off')
# Out:
# (1.0, 3.0, 0.0, 1.0)

# %%
canvas.draw()       # draw the canvas, cache the renderer

# image = np.fromstring(canvas.tostring_rgb(), dtype='uint8')

# %%
image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')

# %%
width, height = fig.get_size_inches() * fig.get_dpi()
img = image.reshape(int(height), int(width), 3)
img2 = np.pad(img, ((1, 1), (1, 1),(0,0)), 'constant', constant_values=(30, 30))

# %%
imgplot = plt.imshow(img2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
img.shape
# Out:
# (480, 640, 3)
